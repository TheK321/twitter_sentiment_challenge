# %%
import re
import string
import pandas as pd
from textblob import TextBlob
import matplotlib.pyplot as plt
import seaborn as sns
from plotly import graph_objs as go
from collections import Counter
import plotly.express as px
import nltk
from nltk.corpus import stopwords
from palettable.colorbrewer.qualitative import Pastel1_7
import numpy as np
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
import nltk
from nltk.corpus import stopwords

# %%
#Función para obtener sentimiento basado en polaridad
def getAnalysis(score):
  if score < 0:
    return 'Negative'
  elif score == 0:
    return 'Neutral'
  else:
    return 'Positive'

# %%
#Función para obtener polaridad y subjetividad
def getPolarity(text):
   return TextBlob(text).sentiment.polarity
def getSubjectivity(text):
   return TextBlob(text).sentiment.subjectivity

# %%
df = pd.read_csv('transday3.csv')
df['TextBlob_Polarity'] =df['Tweet'].apply(getPolarity)
df['TextBlob_Subjectivity'] =df['Tweet'].apply(getSubjectivity)
df['TextBlob_Analysis'] = df['TextBlob_Polarity'].apply(getAnalysis )

# %%
temp = df.groupby('TextBlob_Analysis').count()['Tweet'].reset_index().sort_values(by='Tweet',ascending=False)
temp.style.background_gradient(cmap='Purples')
# Out:
# <style type="text/css">
# #T_06339_row0_col1 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_06339_row1_col1 {
#   background-color: #7567af;
#   color: #f1f1f1;
# }
# #T_06339_row2_col1 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# </style>
# <table id="T_06339">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_06339_level0_col0" class="col_heading level0 col0" >TextBlob_Analysis</th>
#       <th id="T_06339_level0_col1" class="col_heading level0 col1" >Tweet</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_06339_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_06339_row0_col0" class="data row0 col0" >Neutral</td>
#       <td id="T_06339_row0_col1" class="data row0 col1" >25362</td>
#     </tr>
#     <tr>
#       <th id="T_06339_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_06339_row1_col0" class="data row1 col0" >Positive</td>
#       <td id="T_06339_row1_col1" class="data row1 col1" >19130</td>
#     </tr>
#     <tr>
#       <th id="T_06339_level0_row2" class="row_heading level0 row2" >0</th>
#       <td id="T_06339_row2_col0" class="data row2 col0" >Negative</td>
#       <td id="T_06339_row2_col1" class="data row2 col1" >5509</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='TextBlob_Analysis',data=df)
# Out:
# <Axes: xlabel='TextBlob_Analysis', ylabel='count'>

# %%
fig = go.Figure(go.Funnelarea(
    text =temp.TextBlob_Analysis,
    values = temp.Tweet,
    title = {"position": "top center", "text": "Funnel-Chart of Sentiment Distribution"}
    ))
fig.show()

# %%
def clean_text(text):
    '''Make text lowercase, remove text in square brackets,remove links,remove punctuation
    and remove words containing numbers.'''
    text = str(text).lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = re.sub('\s-\s', ' ', text)
    text = re.sub('\.{2,}', '', text)
    return text

# %%
df['Tweet'] = df['Tweet'].apply(lambda x:clean_text(x))
df['temp_list'] = df['Tweet'].apply(lambda x:str(x).split())
def remove_stopword(x):
    return [y for y in x if y not in stopwords.words('english')]
df['temp_list'] = df['temp_list'].apply(lambda x:remove_stopword(x))

# %%
top = Counter([item for sublist in df['temp_list'] for item in sublist])
temp = pd.DataFrame(top.most_common(20))
temp = temp.iloc[1:,:]
temp.columns = ['Common_words','count']
temp.style.background_gradient(cmap='Purples')
# Out:
# <style type="text/css">
# #T_98f2d_row0_col1 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_98f2d_row1_col1 {
#   background-color: #e3e2ef;
#   color: #000000;
# }
# #T_98f2d_row2_col1, #T_98f2d_row3_col1 {
#   background-color: #ecebf4;
#   color: #000000;
# }
# #T_98f2d_row4_col1 {
#   background-color: #f1eff6;
#   color: #000000;
# }
# #T_98f2d_row5_col1 {
#   background-color: #f6f5f9;
#   color: #000000;
# }
# #T_98f2d_row6_col1 {
#   background-color: #f7f5fa;
#   color: #000000;
# }
# #T_98f2d_row7_col1 {
#   background-color: #f8f7fb;
#   color: #000000;
# }
# #T_98f2d_row8_col1, #T_98f2d_row9_col1 {
#   background-color: #faf8fb;
#   color: #000000;
# }
# #T_98f2d_row10_col1, #T_98f2d_row11_col1, #T_98f2d_row12_col1, #T_98f2d_row13_col1, #T_98f2d_row14_col1 {
#   background-color: #faf9fc;
#   color: #000000;
# }
# #T_98f2d_row15_col1, #T_98f2d_row16_col1, #T_98f2d_row17_col1, #T_98f2d_row18_col1 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# </style>
# <table id="T_98f2d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_98f2d_level0_col0" class="col_heading level0 col0" >Common_words</th>
#       <th id="T_98f2d_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_98f2d_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_98f2d_row0_col0" class="data row0 col0" >oscar</td>
#       <td id="T_98f2d_row0_col1" class="data row0 col1" >13988</td>
#     </tr>
#     <tr>
#       <th id="T_98f2d_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_98f2d_row1_col0" class="data row1 col0" >carpet</td>
#       <td id="T_98f2d_row1_col1" class="data row1 col1" >3771</td>
#     </tr>
#     <tr>
#       <th id="T_98f2d_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_98f2d_row2_col0" class="data row2 col0" >best</td>
#       <td id="T_98f2d_row2_col1" class="data row2 col1" >3116</td>
#     </tr>
#     <tr>
#       <th id="T_98f2d_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_98f2d_row3_col0" class="data row3 col0" >red</td>
#       <td id="T_98f2d_row3_col1" class="data row3 col1" >3086</td>
#     </tr>
#     <tr>
#       <th id="T_98f2d_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_98f2d_row4_col0" class="data row4 col0" >see</td>
#       <td id="T_98f2d_row4_col1" class="data row4 col1" >2713</td>
#     </tr>
#     <tr>
#       <th id="T_98f2d_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_98f2d_row5_col0" class="data row5 col0" >like</td>
#       <td id="T_98f2d_row5_col1" class="data row5 col1" >1997</td>
#     </tr>
#     <tr>
#       <th id="T_98f2d_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_98f2d_row6_col0" class="data row6 col0" >win</td>
#       <td id="T_98f2d_row6_col1" class="data row6 col1" >1961</td>
#     </tr>
#     <tr>
#       <th id="T_98f2d_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_98f2d_row7_col0" class="data row7 col0" >watch</td>
#       <td id="T_98f2d_row7_col1" class="data row7 col1" >1752</td>
#     </tr>
#     <tr>
#       <th id="T_98f2d_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_98f2d_row8_col0" class="data row8 col0" >tonight</td>
#       <td id="T_98f2d_row8_col1" class="data row8 col1" >1632</td>
#     </tr>
#     <tr>
#       <th id="T_98f2d_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_98f2d_row9_col0" class="data row9 col0" >time</td>
#       <td id="T_98f2d_row9_col1" class="data row9 col1" >1616</td>
#     </tr>
#     <tr>
#       <th id="T_98f2d_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_98f2d_row10_col0" class="data row10 col0" >live</td>
#       <td id="T_98f2d_row10_col1" class="data row10 col1" >1561</td>
#     </tr>
#     <tr>
#       <th id="T_98f2d_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_98f2d_row11_col0" class="data row11 col0" >love</td>
#       <td id="T_98f2d_row11_col1" class="data row11 col1" >1560</td>
#     </tr>
#     <tr>
#       <th id="T_98f2d_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_98f2d_row12_col0" class="data row12 col0" >year</td>
#       <td id="T_98f2d_row12_col1" class="data row12 col1" >1552</td>
#     </tr>
#     <tr>
#       <th id="T_98f2d_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_98f2d_row13_col0" class="data row13 col0" >awards</td>
#       <td id="T_98f2d_row13_col1" class="data row13 col1" >1545</td>
#     </tr>
#     <tr>
#       <th id="T_98f2d_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_98f2d_row14_col0" class="data row14 col0" >im</td>
#       <td id="T_98f2d_row14_col1" class="data row14 col1" >1509</td>
#     </tr>
#     <tr>
#       <th id="T_98f2d_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_98f2d_row15_col0" class="data row15 col0" >today</td>
#       <td id="T_98f2d_row15_col1" class="data row15 col1" >1360</td>
#     </tr>
#     <tr>
#       <th id="T_98f2d_level0_row16" class="row_heading level0 row16" >17</th>
#       <td id="T_98f2d_row16_col0" class="data row16 col0" >gaga</td>
#       <td id="T_98f2d_row16_col1" class="data row16 col1" >1323</td>
#     </tr>
#     <tr>
#       <th id="T_98f2d_level0_row17" class="row_heading level0 row17" >18</th>
#       <td id="T_98f2d_row17_col0" class="data row17 col0" >looks</td>
#       <td id="T_98f2d_row17_col1" class="data row17 col1" >1290</td>
#     </tr>
#     <tr>
#       <th id="T_98f2d_level0_row18" class="row_heading level0 row18" >19</th>
#       <td id="T_98f2d_row18_col0" class="data row18 col0" >one</td>
#       <td id="T_98f2d_row18_col1" class="data row18 col1" >1285</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = px.bar(temp, x="count", y="Common_words", title='Commmon Words in Selected Text', orientation='h', 
             width=700, height=700,color='Common_words')
fig.show()

# %%
fig = px.treemap(temp, path=['Common_words'], values='count',title='Tree of Most Common Words')
fig.show()

# %%
Positive_sent = df[df['TextBlob_Analysis']=='Positive']
Negative_sent = df[df['TextBlob_Analysis']=='Negative']
Neutral_sent = df[df['TextBlob_Analysis']=='Neutral']

# %%
#MosT common positive words
top = Counter([item for sublist in Positive_sent['temp_list'] for item in sublist])
temp_positive = pd.DataFrame(top.most_common(20))
temp_positive.columns = ['Common_words','count']
temp_positive.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_7a9e7_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_7a9e7_row1_col1 {
#   background-color: #75c477;
#   color: #000000;
# }
# #T_7a9e7_row2_col1 {
#   background-color: #ceecc8;
#   color: #000000;
# }
# #T_7a9e7_row3_col1 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_7a9e7_row4_col1, #T_7a9e7_row5_col1 {
#   background-color: #edf8ea;
#   color: #000000;
# }
# #T_7a9e7_row6_col1 {
#   background-color: #eef8ea;
#   color: #000000;
# }
# #T_7a9e7_row7_col1, #T_7a9e7_row8_col1 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_7a9e7_row9_col1 {
#   background-color: #f4fbf1;
#   color: #000000;
# }
# #T_7a9e7_row10_col1, #T_7a9e7_row11_col1, #T_7a9e7_row12_col1, #T_7a9e7_row13_col1 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_7a9e7_row14_col1, #T_7a9e7_row15_col1, #T_7a9e7_row16_col1, #T_7a9e7_row17_col1 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_7a9e7_row18_col1, #T_7a9e7_row19_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_7a9e7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7a9e7_level0_col0" class="col_heading level0 col0" >Common_words</th>
#       <th id="T_7a9e7_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7a9e7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7a9e7_row0_col0" class="data row0 col0" >oscars</td>
#       <td id="T_7a9e7_row0_col1" class="data row0 col1" >11122</td>
#     </tr>
#     <tr>
#       <th id="T_7a9e7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7a9e7_row1_col0" class="data row1 col0" >oscar</td>
#       <td id="T_7a9e7_row1_col1" class="data row1 col1" >5946</td>
#     </tr>
#     <tr>
#       <th id="T_7a9e7_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7a9e7_row2_col0" class="data row2 col0" >best</td>
#       <td id="T_7a9e7_row2_col1" class="data row2 col1" >3086</td>
#     </tr>
#     <tr>
#       <th id="T_7a9e7_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7a9e7_row3_col0" class="data row3 col0" >win</td>
#       <td id="T_7a9e7_row3_col1" class="data row3 col1" >1830</td>
#     </tr>
#     <tr>
#       <th id="T_7a9e7_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7a9e7_row4_col0" class="data row4 col0" >love</td>
#       <td id="T_7a9e7_row4_col1" class="data row4 col1" >1504</td>
#     </tr>
#     <tr>
#       <th id="T_7a9e7_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7a9e7_row5_col0" class="data row5 col0" >carpet</td>
#       <td id="T_7a9e7_row5_col1" class="data row5 col1" >1481</td>
#     </tr>
#     <tr>
#       <th id="T_7a9e7_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7a9e7_row6_col0" class="data row6 col0" >live</td>
#       <td id="T_7a9e7_row6_col1" class="data row6 col1" >1460</td>
#     </tr>
#     <tr>
#       <th id="T_7a9e7_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7a9e7_row7_col0" class="data row7 col0" >red</td>
#       <td id="T_7a9e7_row7_col1" class="data row7 col1" >1275</td>
#     </tr>
#     <tr>
#       <th id="T_7a9e7_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7a9e7_row8_col0" class="data row8 col0" >see</td>
#       <td id="T_7a9e7_row8_col1" class="data row8 col1" >1226</td>
#     </tr>
#     <tr>
#       <th id="T_7a9e7_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7a9e7_row9_col0" class="data row9 col0" >beautiful</td>
#       <td id="T_7a9e7_row9_col1" class="data row9 col1" >1072</td>
#     </tr>
#     <tr>
#       <th id="T_7a9e7_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_7a9e7_row10_col0" class="data row10 col0" >like</td>
#       <td id="T_7a9e7_row10_col1" class="data row10 col1" >952</td>
#     </tr>
#     <tr>
#       <th id="T_7a9e7_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_7a9e7_row11_col0" class="data row11 col0" >actress</td>
#       <td id="T_7a9e7_row11_col1" class="data row11 col1" >946</td>
#     </tr>
#     <tr>
#       <th id="T_7a9e7_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_7a9e7_row12_col0" class="data row12 col0" >awards</td>
#       <td id="T_7a9e7_row12_col1" class="data row12 col1" >930</td>
#     </tr>
#     <tr>
#       <th id="T_7a9e7_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_7a9e7_row13_col0" class="data row13 col0" >good</td>
#       <td id="T_7a9e7_row13_col1" class="data row13 col1" >923</td>
#     </tr>
#     <tr>
#       <th id="T_7a9e7_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_7a9e7_row14_col0" class="data row14 col0" >tonight</td>
#       <td id="T_7a9e7_row14_col1" class="data row14 col1" >877</td>
#     </tr>
#     <tr>
#       <th id="T_7a9e7_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_7a9e7_row15_col0" class="data row15 col0" >watch</td>
#       <td id="T_7a9e7_row15_col1" class="data row15 col1" >863</td>
#     </tr>
#     <tr>
#       <th id="T_7a9e7_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_7a9e7_row16_col0" class="data row16 col0" >movie</td>
#       <td id="T_7a9e7_row16_col1" class="data row16 col1" >841</td>
#     </tr>
#     <tr>
#       <th id="T_7a9e7_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_7a9e7_row17_col0" class="data row17 col0" >looks</td>
#       <td id="T_7a9e7_row17_col1" class="data row17 col1" >837</td>
#     </tr>
#     <tr>
#       <th id="T_7a9e7_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_7a9e7_row18_col0" class="data row18 col0" >year</td>
#       <td id="T_7a9e7_row18_col1" class="data row18 col1" >825</td>
#     </tr>
#     <tr>
#       <th id="T_7a9e7_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_7a9e7_row19_col0" class="data row19 col0" >time</td>
#       <td id="T_7a9e7_row19_col1" class="data row19 col1" >792</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = px.bar(temp_positive, x="count", y="Common_words", title='Most Commmon Positive Words', orientation='h', 
             width=700, height=700,color='Common_words')
fig.show()

# %%
#MosT common negative words
top = Counter([item for sublist in Negative_sent['temp_list'] for item in sublist])
temp_negative = pd.DataFrame(top.most_common(20))
temp_negative = temp_negative.iloc[1:,:]
temp_negative.columns = ['Common_words','count']
temp_negative.style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_42e50_row0_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_42e50_row1_col1 {
#   background-color: #fcbea5;
#   color: #000000;
# }
# #T_42e50_row2_col1 {
#   background-color: #fdd4c2;
#   color: #000000;
# }
# #T_42e50_row3_col1 {
#   background-color: #fedccd;
#   color: #000000;
# }
# #T_42e50_row4_col1 {
#   background-color: #fee1d4;
#   color: #000000;
# }
# #T_42e50_row5_col1 {
#   background-color: #fee2d5;
#   color: #000000;
# }
# #T_42e50_row6_col1 {
#   background-color: #fee3d6;
#   color: #000000;
# }
# #T_42e50_row7_col1 {
#   background-color: #fee7db;
#   color: #000000;
# }
# #T_42e50_row8_col1 {
#   background-color: #ffebe2;
#   color: #000000;
# }
# #T_42e50_row9_col1 {
#   background-color: #ffeee6;
#   color: #000000;
# }
# #T_42e50_row10_col1 {
#   background-color: #fff0e9;
#   color: #000000;
# }
# #T_42e50_row11_col1, #T_42e50_row12_col1 {
#   background-color: #fff1ea;
#   color: #000000;
# }
# #T_42e50_row13_col1, #T_42e50_row14_col1 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_42e50_row15_col1 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_42e50_row16_col1 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_42e50_row17_col1, #T_42e50_row18_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_42e50">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_42e50_level0_col0" class="col_heading level0 col0" >Common_words</th>
#       <th id="T_42e50_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_42e50_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_42e50_row0_col0" class="data row0 col0" >oscar</td>
#       <td id="T_42e50_row0_col1" class="data row0 col1" >1615</td>
#     </tr>
#     <tr>
#       <th id="T_42e50_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_42e50_row1_col0" class="data row1 col0" >carpet</td>
#       <td id="T_42e50_row1_col1" class="data row1 col1" >531</td>
#     </tr>
#     <tr>
#       <th id="T_42e50_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_42e50_row2_col0" class="data row2 col0" >red</td>
#       <td id="T_42e50_row2_col1" class="data row2 col1" >423</td>
#     </tr>
#     <tr>
#       <th id="T_42e50_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_42e50_row3_col0" class="data row3 col0" >hugh</td>
#       <td id="T_42e50_row3_col1" class="data row3 col1" >382</td>
#     </tr>
#     <tr>
#       <th id="T_42e50_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_42e50_row4_col0" class="data row4 col0" >see</td>
#       <td id="T_42e50_row4_col1" class="data row4 col1" >355</td>
#     </tr>
#     <tr>
#       <th id="T_42e50_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_42e50_row5_col0" class="data row5 col0" >grant</td>
#       <td id="T_42e50_row5_col1" class="data row5 col1" >351</td>
#     </tr>
#     <tr>
#       <th id="T_42e50_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_42e50_row6_col0" class="data row6 col0" >like</td>
#       <td id="T_42e50_row6_col1" class="data row6 col1" >347</td>
#     </tr>
#     <tr>
#       <th id="T_42e50_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_42e50_row7_col0" class="data row7 col0" >im</td>
#       <td id="T_42e50_row7_col1" class="data row7 col1" >312</td>
#     </tr>
#     <tr>
#       <th id="T_42e50_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_42e50_row8_col0" class="data row8 col0" >watch</td>
#       <td id="T_42e50_row8_col1" class="data row8 col1" >270</td>
#     </tr>
#     <tr>
#       <th id="T_42e50_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_42e50_row9_col0" class="data row9 col0" >interview</td>
#       <td id="T_42e50_row9_col1" class="data row9 col1" >251</td>
#     </tr>
#     <tr>
#       <th id="T_42e50_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_42e50_row10_col0" class="data row10 col0" >bad</td>
#       <td id="T_42e50_row10_col1" class="data row10 col1" >229</td>
#     </tr>
#     <tr>
#       <th id="T_42e50_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_42e50_row11_col0" class="data row11 col0" >year</td>
#       <td id="T_42e50_row11_col1" class="data row11 col1" >223</td>
#     </tr>
#     <tr>
#       <th id="T_42e50_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_42e50_row12_col0" class="data row12 col0" >little</td>
#       <td id="T_42e50_row12_col1" class="data row12 col1" >220</td>
#     </tr>
#     <tr>
#       <th id="T_42e50_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_42e50_row13_col0" class="data row13 col0" >time</td>
#       <td id="T_42e50_row13_col1" class="data row13 col1" >219</td>
#     </tr>
#     <tr>
#       <th id="T_42e50_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_42e50_row14_col0" class="data row14 col0" >black</td>
#       <td id="T_42e50_row14_col1" class="data row14 col1" >219</td>
#     </tr>
#     <tr>
#       <th id="T_42e50_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_42e50_row15_col0" class="data row15 col0" >watching</td>
#       <td id="T_42e50_row15_col1" class="data row15 col1" >198</td>
#     </tr>
#     <tr>
#       <th id="T_42e50_level0_row16" class="row_heading level0 row16" >17</th>
#       <td id="T_42e50_row16_col0" class="data row16 col0" >one</td>
#       <td id="T_42e50_row16_col1" class="data row16 col1" >194</td>
#     </tr>
#     <tr>
#       <th id="T_42e50_level0_row17" class="row_heading level0 row17" >18</th>
#       <td id="T_42e50_row17_col0" class="data row17 col0" >people</td>
#       <td id="T_42e50_row17_col1" class="data row17 col1" >188</td>
#     </tr>
#     <tr>
#       <th id="T_42e50_level0_row18" class="row_heading level0 row18" >19</th>
#       <td id="T_42e50_row18_col0" class="data row18 col0" >fuck</td>
#       <td id="T_42e50_row18_col1" class="data row18 col1" >186</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = px.treemap(temp_negative, path=['Common_words'], values='count',title='Tree Of Most Common Negative Words')
fig.show()

# %%
#MosT common Neutral words
top = Counter([item for sublist in Neutral_sent['temp_list'] for item in sublist])
temp_neutral = pd.DataFrame(top.most_common(20))
temp_neutral = temp_neutral.loc[1:,:]
temp_neutral.columns = ['Common_words','count']
temp_neutral.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_72a9b_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_72a9b_row1_col1 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_72a9b_row2_col1 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_72a9b_row3_col1 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_72a9b_row4_col1 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_72a9b_row5_col1 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_72a9b_row6_col1 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_72a9b_row7_col1 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_72a9b_row8_col1, #T_72a9b_row9_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_72a9b_row10_col1, #T_72a9b_row11_col1 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_72a9b_row12_col1, #T_72a9b_row13_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_72a9b_row14_col1, #T_72a9b_row15_col1, #T_72a9b_row16_col1, #T_72a9b_row17_col1, #T_72a9b_row18_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_72a9b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_72a9b_level0_col0" class="col_heading level0 col0" >Common_words</th>
#       <th id="T_72a9b_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72a9b_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_72a9b_row0_col0" class="data row0 col0" >oscar</td>
#       <td id="T_72a9b_row0_col1" class="data row0 col1" >6427</td>
#     </tr>
#     <tr>
#       <th id="T_72a9b_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_72a9b_row1_col0" class="data row1 col0" >carpet</td>
#       <td id="T_72a9b_row1_col1" class="data row1 col1" >1759</td>
#     </tr>
#     <tr>
#       <th id="T_72a9b_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_72a9b_row2_col0" class="data row2 col0" >red</td>
#       <td id="T_72a9b_row2_col1" class="data row2 col1" >1388</td>
#     </tr>
#     <tr>
#       <th id="T_72a9b_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_72a9b_row3_col0" class="data row3 col0" >see</td>
#       <td id="T_72a9b_row3_col1" class="data row3 col1" >1132</td>
#     </tr>
#     <tr>
#       <th id="T_72a9b_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_72a9b_row4_col0" class="data row4 col0" >gaga</td>
#       <td id="T_72a9b_row4_col1" class="data row4 col1" >883</td>
#     </tr>
#     <tr>
#       <th id="T_72a9b_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_72a9b_row5_col0" class="data row5 col0" >pedro</td>
#       <td id="T_72a9b_row5_col1" class="data row5 col1" >836</td>
#     </tr>
#     <tr>
#       <th id="T_72a9b_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_72a9b_row6_col0" class="data row6 col0" >arrived</td>
#       <td id="T_72a9b_row6_col1" class="data row6 col1" >735</td>
#     </tr>
#     <tr>
#       <th id="T_72a9b_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_72a9b_row7_col0" class="data row7 col0" >like</td>
#       <td id="T_72a9b_row7_col1" class="data row7 col1" >698</td>
#     </tr>
#     <tr>
#       <th id="T_72a9b_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_72a9b_row8_col0" class="data row8 col0" >pascal</td>
#       <td id="T_72a9b_row8_col1" class="data row8 col1" >687</td>
#     </tr>
#     <tr>
#       <th id="T_72a9b_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_72a9b_row9_col0" class="data row9 col0" >lady</td>
#       <td id="T_72a9b_row9_col1" class="data row9 col1" >686</td>
#     </tr>
#     <tr>
#       <th id="T_72a9b_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_72a9b_row10_col0" class="data row10 col0" >watch</td>
#       <td id="T_72a9b_row10_col1" class="data row10 col1" >619</td>
#     </tr>
#     <tr>
#       <th id="T_72a9b_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_72a9b_row11_col0" class="data row11 col0" >time</td>
#       <td id="T_72a9b_row11_col1" class="data row11 col1" >605</td>
#     </tr>
#     <tr>
#       <th id="T_72a9b_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_72a9b_row12_col0" class="data row12 col0" >tonight</td>
#       <td id="T_72a9b_row12_col1" class="data row12 col1" >594</td>
#     </tr>
#     <tr>
#       <th id="T_72a9b_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_72a9b_row13_col0" class="data row13 col0" >today</td>
#       <td id="T_72a9b_row13_col1" class="data row13 col1" >580</td>
#     </tr>
#     <tr>
#       <th id="T_72a9b_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_72a9b_row14_col0" class="data row14 col0" >michelle</td>
#       <td id="T_72a9b_row14_col1" class="data row14 col1" >518</td>
#     </tr>
#     <tr>
#       <th id="T_72a9b_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_72a9b_row15_col0" class="data row15 col0" >watching</td>
#       <td id="T_72a9b_row15_col1" class="data row15 col1" >512</td>
#     </tr>
#     <tr>
#       <th id="T_72a9b_level0_row16" class="row_heading level0 row16" >17</th>
#       <td id="T_72a9b_row16_col0" class="data row16 col0" >awards</td>
#       <td id="T_72a9b_row16_col1" class="data row16 col1" >510</td>
#     </tr>
#     <tr>
#       <th id="T_72a9b_level0_row17" class="row_heading level0 row17" >18</th>
#       <td id="T_72a9b_row17_col0" class="data row17 col0" >go</td>
#       <td id="T_72a9b_row17_col1" class="data row17 col1" >508</td>
#     </tr>
#     <tr>
#       <th id="T_72a9b_level0_row18" class="row_heading level0 row18" >19</th>
#       <td id="T_72a9b_row18_col0" class="data row18 col0" >year</td>
#       <td id="T_72a9b_row18_col1" class="data row18 col1" >504</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = px.bar(temp_neutral, x="count", y="Common_words", title='Most Commmon Neutral Words', orientation='h', 
             width=700, height=700,color='Common_words')
fig.show()

# %%
fig = px.treemap(temp_neutral, path=['Common_words'], values='count',title='Tree Of Most Common Neutral Words')
fig.show()

# %%
df['temp_list1'] = df['Tweet'].apply(lambda x:str(x).split()) #List of words in every row for text
df['temp_list1'] = df['temp_list1'].apply(lambda x:remove_stopword(x)) #Removing Stopwords
raw_text = [word for word_list in df['temp_list1'] for word in word_list]

# %%
def words_unique(sentiment,numwords,raw_words):
    '''
    Input:
        segment - Segment category (ex. 'Neutral');
        numwords - how many specific words do you want to see in the final result; 
        raw_words - list  for item in train_data[train_data.segments == segments]['temp_list1']:
    Output: 
        dataframe giving information about the name of the specific ingredient and how many times it occurs in the chosen cuisine (in descending order based on their counts)..

    '''
    allother = []
    for item in df[df.TextBlob_Analysis != sentiment]['temp_list1']:
        for word in item:
            allother .append(word)
    allother  = list(set(allother ))
    
    specificnonly = [x for x in raw_text if x not in allother]
    
    mycounter = Counter()
    
    for item in df[df.TextBlob_Analysis == sentiment]['temp_list1']:
        for word in item:
            mycounter[word] += 1
    keep = list(specificnonly)
    
    for word in list(mycounter):
        if word not in keep:
            del mycounter[word]
    
    Unique_words = pd.DataFrame(mycounter.most_common(numwords), columns = ['words','count'])
    
    return Unique_words

# %%
Unique_Positive= words_unique('Positive', 20, raw_text)
print("The top 20 unique words in Positive Tweets are:")
Unique_Positive.style.background_gradient(cmap='Greens')
# Out:
# The top 20 unique words in Positive Tweets are:
# <style type="text/css">
# #T_c3bc1_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_c3bc1_row1_col1 {
#   background-color: #258d47;
#   color: #f1f1f1;
# }
# #T_c3bc1_row2_col1 {
#   background-color: #48ae60;
#   color: #f1f1f1;
# }
# #T_c3bc1_row3_col1 {
#   background-color: #a4da9e;
#   color: #000000;
# }
# #T_c3bc1_row4_col1 {
#   background-color: #a7dba0;
#   color: #000000;
# }
# #T_c3bc1_row5_col1, #T_c3bc1_row6_col1, #T_c3bc1_row7_col1 {
#   background-color: #c7e9c0;
#   color: #000000;
# }
# #T_c3bc1_row8_col1 {
#   background-color: #d0edca;
#   color: #000000;
# }
# #T_c3bc1_row9_col1 {
#   background-color: #d8f0d2;
#   color: #000000;
# }
# #T_c3bc1_row10_col1 {
#   background-color: #def2d9;
#   color: #000000;
# }
# #T_c3bc1_row11_col1 {
#   background-color: #e1f3dc;
#   color: #000000;
# }
# #T_c3bc1_row12_col1 {
#   background-color: #e7f6e2;
#   color: #000000;
# }
# #T_c3bc1_row13_col1 {
#   background-color: #e8f6e3;
#   color: #000000;
# }
# #T_c3bc1_row14_col1 {
#   background-color: #ecf8e8;
#   color: #000000;
# }
# #T_c3bc1_row15_col1 {
#   background-color: #edf8ea;
#   color: #000000;
# }
# #T_c3bc1_row16_col1, #T_c3bc1_row17_col1 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# #T_c3bc1_row18_col1 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_c3bc1_row19_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_c3bc1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c3bc1_level0_col0" class="col_heading level0 col0" >words</th>
#       <th id="T_c3bc1_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c3bc1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c3bc1_row0_col0" class="data row0 col0" >incredible</td>
#       <td id="T_c3bc1_row0_col1" class="data row0 col1" >126</td>
#     </tr>
#     <tr>
#       <th id="T_c3bc1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c3bc1_row1_col0" class="data row1 col0" >🔴live🔴📱➤➤</td>
#       <td id="T_c3bc1_row1_col1" class="data row1 col1" >99</td>
#     </tr>
#     <tr>
#       <th id="T_c3bc1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c3bc1_row2_col0" class="data row2 col0" >spectacular</td>
#       <td id="T_c3bc1_row2_col1" class="data row2 col1" >85</td>
#     </tr>
#     <tr>
#       <th id="T_c3bc1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c3bc1_row3_col0" class="data row3 col0" >hahaha</td>
#       <td id="T_c3bc1_row3_col1" class="data row3 col1" >60</td>
#     </tr>
#     <tr>
#       <th id="T_c3bc1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c3bc1_row4_col0" class="data row4 col0" >greatest</td>
#       <td id="T_c3bc1_row4_col1" class="data row4 col1" >59</td>
#     </tr>
#     <tr>
#       <th id="T_c3bc1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c3bc1_row5_col0" class="data row5 col0" >♥</td>
#       <td id="T_c3bc1_row5_col1" class="data row5 col1" >48</td>
#     </tr>
#     <tr>
#       <th id="T_c3bc1_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c3bc1_row6_col0" class="data row6 col0" >talented</td>
#       <td id="T_c3bc1_row6_col1" class="data row6 col1" >48</td>
#     </tr>
#     <tr>
#       <th id="T_c3bc1_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c3bc1_row7_col0" class="data row7 col0" >⃣</td>
#       <td id="T_c3bc1_row7_col1" class="data row7 col1" >48</td>
#     </tr>
#     <tr>
#       <th id="T_c3bc1_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_c3bc1_row8_col0" class="data row8 col0" >impeccable</td>
#       <td id="T_c3bc1_row8_col1" class="data row8 col1" >44</td>
#     </tr>
#     <tr>
#       <th id="T_c3bc1_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_c3bc1_row9_col0" class="data row9 col0" >freemobile⤵️pc⤵️⃣</td>
#       <td id="T_c3bc1_row9_col1" class="data row9 col1" >41</td>
#     </tr>
#     <tr>
#       <th id="T_c3bc1_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_c3bc1_row10_col0" class="data row10 col0" >➡️</td>
#       <td id="T_c3bc1_row10_col1" class="data row10 col1" >38</td>
#     </tr>
#     <tr>
#       <th id="T_c3bc1_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_c3bc1_row11_col0" class="data row11 col0" >fraserbest</td>
#       <td id="T_c3bc1_row11_col1" class="data row11 col1" >37</td>
#     </tr>
#     <tr>
#       <th id="T_c3bc1_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_c3bc1_row12_col0" class="data row12 col0" >magic</td>
#       <td id="T_c3bc1_row12_col1" class="data row12 col1" >34</td>
#     </tr>
#     <tr>
#       <th id="T_c3bc1_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_c3bc1_row13_col0" class="data row13 col0" >excellent</td>
#       <td id="T_c3bc1_row13_col1" class="data row13 col1" >33</td>
#     </tr>
#     <tr>
#       <th id="T_c3bc1_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_c3bc1_row14_col0" class="data row14 col0" >awesome</td>
#       <td id="T_c3bc1_row14_col1" class="data row14 col1" >30</td>
#     </tr>
#     <tr>
#       <th id="T_c3bc1_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_c3bc1_row15_col0" class="data row15 col0" >latest</td>
#       <td id="T_c3bc1_row15_col1" class="data row15 col1" >29</td>
#     </tr>
#     <tr>
#       <th id="T_c3bc1_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_c3bc1_row16_col0" class="data row16 col0" >bright</td>
#       <td id="T_c3bc1_row16_col1" class="data row16 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_c3bc1_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_c3bc1_row17_col0" class="data row17 col0" >brilliant</td>
#       <td id="T_c3bc1_row17_col1" class="data row17 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_c3bc1_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_c3bc1_row18_col0" class="data row18 col0" >𝐇𝐃</td>
#       <td id="T_c3bc1_row18_col1" class="data row18 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_c3bc1_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_c3bc1_row19_col0" class="data row19 col0" >quanbest</td>
#       <td id="T_c3bc1_row19_col1" class="data row19 col1" >22</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = px.treemap(Unique_Positive, path=['words'], values='count',title='Tree Of Unique Positive Words')
fig.show()

# %%
plt.figure(figsize=(16,10))
my_circle=plt.Circle((0,0), 0.7, color='white')
plt.pie(Unique_Positive['count'], labels=Unique_Positive.words, colors=Pastel1_7.hex_colors)
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.title('DoNut Plot Of Unique Positive Words')
plt.show()
# Out:
# C:\Users\17mar\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning:
#
# Glyph 128308 (\N{LARGE RED CIRCLE}) missing from current font.
#
# C:\Users\17mar\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning:
#
# Glyph 128241 (\N{MOBILE PHONE}) missing from current font.
#
# C:\Users\17mar\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning:
#
# Glyph 8419 (\N{COMBINING ENCLOSING KEYCAP}) missing from current font.
#
# C:\Users\17mar\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning:
#
# Glyph 10549 (\N{ARROW POINTING RIGHTWARDS THEN CURVING DOWNWARDS}) missing from current font.
#
# C:\Users\17mar\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning:
#
# Glyph 119815 (\N{MATHEMATICAL BOLD CAPITAL H}) missing from current font.
#
# C:\Users\17mar\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning:
#
# Glyph 119811 (\N{MATHEMATICAL BOLD CAPITAL D}) missing from current font.

# %%
Unique_Negative= words_unique('Negative', 10, raw_text)
print("The top 10 unique words in Negative Tweets are:")
Unique_Negative.style.background_gradient(cmap='Reds')
# Out:
# The top 10 unique words in Negative Tweets are:
# <style type="text/css">
# #T_b242f_row0_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_b242f_row1_col1 {
#   background-color: #d52221;
#   color: #f1f1f1;
# }
# #T_b242f_row2_col1 {
#   background-color: #fc8161;
#   color: #f1f1f1;
# }
# #T_b242f_row3_col1 {
#   background-color: #fc9879;
#   color: #000000;
# }
# #T_b242f_row4_col1 {
#   background-color: #fdc6b0;
#   color: #000000;
# }
# #T_b242f_row5_col1 {
#   background-color: #fedbcc;
#   color: #000000;
# }
# #T_b242f_row6_col1 {
#   background-color: #fee9df;
#   color: #000000;
# }
# #T_b242f_row7_col1, #T_b242f_row8_col1, #T_b242f_row9_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_b242f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b242f_level0_col0" class="col_heading level0 col0" >words</th>
#       <th id="T_b242f_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b242f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b242f_row0_col0" class="data row0 col0" >chicken</td>
#       <td id="T_b242f_row0_col1" class="data row0 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_b242f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b242f_row1_col0" class="data row1 col0" >lame</td>
#       <td id="T_b242f_row1_col1" class="data row1 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_b242f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b242f_row2_col0" class="data row2 col0" >disgusting</td>
#       <td id="T_b242f_row2_col1" class="data row2 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_b242f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b242f_row3_col0" class="data row3 col0" >nasty</td>
#       <td id="T_b242f_row3_col1" class="data row3 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_b242f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b242f_row4_col0" class="data row4 col0" >outraged</td>
#       <td id="T_b242f_row4_col1" class="data row4 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_b242f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b242f_row5_col0" class="data row5 col0" >miserable</td>
#       <td id="T_b242f_row5_col1" class="data row5 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_b242f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b242f_row6_col0" class="data row6 col0" >unnecessary</td>
#       <td id="T_b242f_row6_col1" class="data row6 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_b242f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b242f_row7_col0" class="data row7 col0" >atrocious</td>
#       <td id="T_b242f_row7_col1" class="data row7 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_b242f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b242f_row8_col0" class="data row8 col0" >salaries</td>
#       <td id="T_b242f_row8_col1" class="data row8 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_b242f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b242f_row9_col0" class="data row9 col0" >vary</td>
#       <td id="T_b242f_row9_col1" class="data row9 col1" >6</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.figure(figsize=(16,10))
my_circle=plt.Circle((0,0), 0.7, color='white')
plt.rcParams['text.color'] = 'black'
plt.pie(Unique_Negative['count'], labels=Unique_Negative.words, colors=Pastel1_7.hex_colors)
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.title('DoNut Plot Of Unique Negative Words')
plt.show()

# %%
Unique_Neutral= words_unique('Neutral', 10, raw_text)
print("The top 10 unique words in Neutral Tweets are:")
Unique_Neutral.style.background_gradient(cmap='Oranges')
# Out:
# The top 10 unique words in Neutral Tweets are:
# <style type="text/css">
# #T_b010d_row0_col1 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_b010d_row1_col1 {
#   background-color: #e25508;
#   color: #f1f1f1;
# }
# #T_b010d_row2_col1, #T_b010d_row3_col1, #T_b010d_row4_col1 {
#   background-color: #f3701b;
#   color: #f1f1f1;
# }
# #T_b010d_row5_col1 {
#   background-color: #fd8c3b;
#   color: #f1f1f1;
# }
# #T_b010d_row6_col1, #T_b010d_row7_col1 {
#   background-color: #fda762;
#   color: #000000;
# }
# #T_b010d_row8_col1 {
#   background-color: #fdd9b4;
#   color: #000000;
# }
# #T_b010d_row9_col1 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# </style>
# <table id="T_b010d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b010d_level0_col0" class="col_heading level0 col0" >words</th>
#       <th id="T_b010d_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b010d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b010d_row0_col0" class="data row0 col0" >tapete</td>
#       <td id="T_b010d_row0_col1" class="data row0 col1" >19</td>
#     </tr>
#     <tr>
#       <th id="T_b010d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b010d_row1_col0" class="data row1 col0" >yargı</td>
#       <td id="T_b010d_row1_col1" class="data row1 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_b010d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b010d_row2_col0" class="data row2 col0" >awardsceremony</td>
#       <td id="T_b010d_row2_col1" class="data row2 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_b010d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b010d_row3_col0" class="data row3 col0" >봄</td>
#       <td id="T_b010d_row3_col1" class="data row3 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_b010d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b010d_row4_col0" class="data row4 col0" >물셋</td>
#       <td id="T_b010d_row4_col1" class="data row4 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_b010d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b010d_row5_col0" class="data row5 col0" >celebeventshqhotcelebladies</td>
#       <td id="T_b010d_row5_col1" class="data row5 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_b010d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b010d_row6_col0" class="data row6 col0" >declines</td>
#       <td id="T_b010d_row6_col1" class="data row6 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_b010d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b010d_row7_col0" class="data row7 col0" >hughgrantsucks</td>
#       <td id="T_b010d_row7_col1" class="data row7 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_b010d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b010d_row8_col0" class="data row8 col0" >dona</td>
#       <td id="T_b010d_row8_col1" class="data row8 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_b010d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b010d_row9_col0" class="data row9 col0" >🤔😅</td>
#       <td id="T_b010d_row9_col1" class="data row9 col1" >9</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.figure(figsize=(16,10))
my_circle=plt.Circle((0,0), 0.7, color='white')
plt.pie(Unique_Neutral['count'], labels=Unique_Neutral.words, colors=Pastel1_7.hex_colors)
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.title('DoNut Plot Of Unique Neutral Words')
plt.show()
# Out:
# C:\Users\17mar\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning:
#
# Glyph 48388 (\N{HANGUL SYLLABLE BOM}) missing from current font.
#
# C:\Users\17mar\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning:
#
# Glyph 47932 (\N{HANGUL SYLLABLE MUL}) missing from current font.
#
# C:\Users\17mar\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning:
#
# Glyph 49483 (\N{HANGUL SYLLABLE SES}) missing from current font.
#
# C:\Users\17mar\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning:
#
# Glyph 129300 (\N{THINKING FACE}) missing from current font.

# %%
def plot_wordcloud(text, mask=None, max_words=200, max_font_size=100, figure_size=(24.0,16.0), color = 'white',
                   title = None, title_size=40, image_color=False):
    stopwords = set(STOPWORDS)
    more_stopwords = {'u', "im"}
    stopwords = stopwords.union(more_stopwords)

    wordcloud = WordCloud(background_color=color,
                    stopwords = stopwords,
                    max_words = max_words,
                    max_font_size = max_font_size, 
                    random_state = 42,
                    width=400, 
                    height=200,
                    mask = mask)
    wordcloud.generate(str(text))
    
    plt.figure(figsize=figure_size)
    if image_color:
        image_colors = ImageColorGenerator(mask);
        plt.imshow(wordcloud.recolor(color_func=image_colors), interpolation="bilinear");
        plt.title(title, fontdict={'size': title_size,  
                                  'verticalalignment': 'bottom'})
    else:
        plt.imshow(wordcloud);
        plt.title(title, fontdict={'size': title_size, 'color': 'black', 
                                  'verticalalignment': 'bottom'})
    plt.axis('off');
    plt.tight_layout()

# %%
pos_mask = np.array(Image.open('statue.png'))
plot_wordcloud(Neutral_sent.Tweet,mask=pos_mask,color='white',max_font_size=100,title_size=30,title="WordCloud of Neutral Tweets")

# %%
plot_wordcloud(Positive_sent.Tweet,mask=pos_mask,title="Word Cloud Of Positive tweets",title_size=30)

# %%
print(df.sort_values(by=['TextBlob_Polarity']))
# Out:
#        Unnamed: 0             User               Date Created  \
# 36526       36526         Paul_y09  2023-03-12 23:34:29+00:00
# 15610       15610      Max69621021  2023-03-12 23:49:26+00:00
# 21152       21152     justlikespos  2023-03-12 23:45:38+00:00
# 6511         6511     robertossani  2023-03-12 23:55:41+00:00
# 21148       21148       panda1jen0  2023-03-12 23:45:38+00:00
# ...           ...              ...                        ...
# 10382       10382        iam_matik  2023-03-12 23:53:04+00:00
# 18103       18103        segueoruy  2023-03-12 23:47:46+00:00
# 4785         4785         Lupemunz  2023-03-12 23:56:48+00:00
# 14469       14469        O_jatinho  2023-03-12 23:50:15+00:00
# 45160       45160  sassygirlcanada  2023-03-12 23:27:31+00:00
#
#        Number of Likes      Source of Tweet  \
# 36526                0   Twitter for iPhone
# 15610                2  Twitter for Android
# 21152                1  Twitter for Android
# 6511                 0  Twitter for Android
# 21148                2   Twitter for iPhone
# ...                ...                  ...
# 10382                1  Twitter for Android
# 18103                0  Twitter for Android
# 4785                 1  Twitter for Android
# 14469                0      Twitter Web App
# 45160                0  Twitter for Android
#
#                                                    Tweet  TextBlob_Polarity  \
# 36526        this is boring and worst of the  noms oscar               -1.0
# 15610               bah humbug i hate movies 😡😡😡 oscars                -1.0
# 21152  the way we scratch the walls x see it in the o...               -1.0
# 6511   this trio that is presenting oscars on tnt is ...               -1.0
# 21148  hugh grant was so awful let’s never interview ...               -1.0
# ...                                                  ...                ...
# 10382                  cate blanchettbest actressoscars                 1.0
# 18103  best actress oscarsmy fans cate blanchettmy be...                1.0
# 4785   and of all i have seen this is the best look 👇...                1.0
# 14469  and lets go to oscars oscarpeeweee ♥ ️ with th...                1.0
# 45160            people so unbelievably beautiful oscars                1.0
#
#        TextBlob_Subjectivity TextBlob_Analysis  \
# 36526                   1.00          Negative
# 15610                   0.90          Negative
# 21152                   1.00          Negative
# 6511                    1.00          Negative
# 21148                   1.00          Negative
# ...                      ...               ...
# 10382                   0.30          Positive
# 18103                   0.30          Positive
# 4785                    0.30          Positive
# 14469                   0.65          Positive
# 45160                   1.00          Positive
#
#                                                temp_list  \
# 36526                       [boring, worst, noms, oscar]
# 15610           [bah, humbug, hate, movies, 😡😡😡, oscars]
# 21152    [way, scratch, walls, x, see, oscars, terrible]
# 6511   [trio, presenting, oscars, tnt, boring, pqp, v...
# 21148  [hugh, grant, awful, let’s, never, interview, ...
# ...                                                  ...
# 10382               [cate, blanchettbest, actressoscars]
# 18103  [best, actress, oscarsmy, fans, cate, blanchet...
# 4785                         [seen, best, look, 👇oscars]
# 14469       [lets, go, oscars, oscarpeeweee, ♥, ️, best]
# 45160          [people, unbelievably, beautiful, oscars]
#
#                                               temp_list1
# 36526                       [boring, worst, noms, oscar]
# 15610           [bah, humbug, hate, movies, 😡😡😡, oscars]
# 21152    [way, scratch, walls, x, see, oscars, terrible]
# 6511   [trio, presenting, oscars, tnt, boring, pqp, v...
# 21148  [hugh, grant, awful, let’s, never, interview, ...
# ...                                                  ...
# 10382               [cate, blanchettbest, actressoscars]
# 18103  [best, actress, oscarsmy, fans, cate, blanchet...
# 4785                         [seen, best, look, 👇oscars]
# 14469       [lets, go, oscars, oscarpeeweee, ♥, ️, best]
# 45160          [people, unbelievably, beautiful, oscars]
#
# [50001 rows x 11 columns]

# %%
print(df[df['TextBlob_Polarity']==0])
# Out:
#        Unnamed: 0             User               Date Created  \
# 0               0          Raviotx  2023-03-12 23:59:59+00:00
# 2               2   Kennethaylett3  2023-03-12 23:59:59+00:00
# 3               3        welvtimmy  2023-03-12 23:59:59+00:00
# 5               5    MatthewLiedke  2023-03-12 23:59:59+00:00
# 7               7      Spaceballs_  2023-03-12 23:59:59+00:00
# ...           ...              ...                        ...
# 49988       49988  tamutaro_desuyo  2023-03-12 23:23:23+00:00
# 49989       49989     AJPrincess78  2023-03-12 23:23:23+00:00
# 49990       49990      Sad_Mochi17  2023-03-12 23:23:23+00:00
# 49997       49997   ElielsonJnior1  2023-03-12 23:23:22+00:00
# 49999       49999          drun007  2023-03-12 23:23:22+00:00
#
#        Number of Likes      Source of Tweet  \
# 0                    0  Twitter for Android
# 2                    0  Twitter for Android
# 3                    0   Twitter for iPhone
# 5                    0   Twitter for iPhone
# 7                    5      Twitter Web App
# ...                ...                  ...
# 49988                2   Twitter for iPhone
# 49989                0  Twitter for Android
# 49990                0  Twitter for Android
# 49997                2   Twitter for iPhone
# 49999                2   Twitter for iPhone
#
#                                                    Tweet  TextBlob_Polarity  \
# 0                  what do you think of this look oscars                0.0
# 2                     night of chill watching the oscars                0.0
# 3                                   justin in the oscars                0.0
# 5      what’s everyone sipping on tonight peanut butt...                0.0
# 7                                               oscars                  0.0
# ...                                                  ...                ...
# 49988  i wont work today until the award ceremony is ...                0.0
# 49989        i havent watched any of these movies oscars                0.0
# 49990                                     paolooo oscars                0.0
# 49997                    tachycardia with this oscar saw                0.0
# 49999  all set for afsheensoscars my annual date with...                0.0
#
#        TextBlob_Subjectivity TextBlob_Analysis  \
# 0                        0.0           Neutral
# 2                        0.0           Neutral
# 3                        0.0           Neutral
# 5                        0.0           Neutral
# 7                        0.0           Neutral
# ...                      ...               ...
# 49988                    0.0           Neutral
# 49989                    0.0           Neutral
# 49990                    0.0           Neutral
# 49997                    0.0           Neutral
# 49999                    0.0           Neutral
#
#                                                temp_list  \
# 0                                  [think, look, oscars]
# 2                       [night, chill, watching, oscars]
# 3                                       [justin, oscars]
# 5      [what’s, everyone, sipping, tonight, peanut, b...
# 7                                               [oscars]
# ...                                                  ...
# 49988   [wont, work, today, award, ceremony, overoscars]
# 49989                  [havent, watched, movies, oscars]
# 49990                                  [paolooo, oscars]
# 49997                          [tachycardia, oscar, saw]
# 49999  [set, afsheensoscars, annual, date, scintillac...
#
#                                               temp_list1
# 0                                  [think, look, oscars]
# 2                       [night, chill, watching, oscars]
# 3                                       [justin, oscars]
# 5      [what’s, everyone, sipping, tonight, peanut, b...
# 7                                               [oscars]
# ...                                                  ...
# 49988   [wont, work, today, award, ceremony, overoscars]
# 49989                  [havent, watched, movies, oscars]
# 49990                                  [paolooo, oscars]
# 49997                          [tachycardia, oscar, saw]
# 49999  [set, afsheensoscars, annual, date, scintillac...
#
# [25362 rows x 11 columns]

# %%
# Filtrar el dataframe para excluir los valores de 0 y 1
df_filtrado = df[(df['TextBlob_Subjectivity'] > 0) & (df['TextBlob_Subjectivity'] < 1) & (df['TextBlob_Subjectivity'] != 0.5)]

# Agrupar los datos filtrados y contar el número de registros en cada grupo
conteo_por_grupo = df_filtrado.groupby('TextBlob_Subjectivity').count()

# Crear una gráfica de dispersión
plt.scatter(conteo_por_grupo.index, conteo_por_grupo['TextBlob_Analysis'])

# Configurar los títulos y etiquetas de los ejes
plt.title('Gráfica de dispersión de la columna TextBlob_Subjectivity')
plt.xlabel('TextBlob_Subjectivity')
plt.ylabel('Número de registros')

# Mostrar la gráfica
plt.show()
