# %%
import re
import string
import pandas as pd
from textblob import TextBlob
import matplotlib.pyplot as plt
import seaborn as sns
from plotly import graph_objs as go
from collections import Counter
import plotly.express as px
import nltk
from nltk.corpus import stopwords
from palettable.colorbrewer.qualitative import Pastel1_7
import numpy as np
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
import nltk
from nltk.corpus import stopwords

# %%
#Función para obtener sentimiento basado en polaridad
def getAnalysis(score):
  if score < 0:
    return 'Negative'
  elif score == 0:
    return 'Neutral'
  else:
    return 'Positive'

# %%
#Función para obtener polaridad y subjetividad
def getPolarity(text):
   return TextBlob(text).sentiment.polarity
def getSubjectivity(text):
   return TextBlob(text).sentiment.subjectivity

# %%
df = pd.read_csv('transday1.csv')
df['TextBlob_Polarity'] =df['Tweet'].apply(getPolarity)
df['TextBlob_Subjectivity'] =df['Tweet'].apply(getSubjectivity)
df['TextBlob_Analysis'] = df['TextBlob_Polarity'].apply(getAnalysis )

# %%
temp = df.groupby('TextBlob_Analysis').count()['Tweet'].reset_index().sort_values(by='Tweet',ascending=False)
temp.style.background_gradient(cmap='Purples')
# Out:
# <style type="text/css">
# #T_400df_row0_col1 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_400df_row1_col1 {
#   background-color: #674ca1;
#   color: #f1f1f1;
# }
# #T_400df_row2_col1 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# </style>
# <table id="T_400df">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_400df_level0_col0" class="col_heading level0 col0" >TextBlob_Analysis</th>
#       <th id="T_400df_level0_col1" class="col_heading level0 col1" >Tweet</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_400df_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_400df_row0_col0" class="data row0 col0" >Neutral</td>
#       <td id="T_400df_row0_col1" class="data row0 col1" >23885</td>
#     </tr>
#     <tr>
#       <th id="T_400df_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_400df_row1_col0" class="data row1 col0" >Positive</td>
#       <td id="T_400df_row1_col1" class="data row1 col1" >19734</td>
#     </tr>
#     <tr>
#       <th id="T_400df_level0_row2" class="row_heading level0 row2" >0</th>
#       <td id="T_400df_row2_col0" class="data row2 col0" >Negative</td>
#       <td id="T_400df_row2_col1" class="data row2 col1" >6382</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.figure(figsize=(12,6))
sns.countplot(x='TextBlob_Analysis',data=df)
# Out:
# <Axes: xlabel='TextBlob_Analysis', ylabel='count'>

# %%
fig = go.Figure(go.Funnelarea(
    text =temp.TextBlob_Analysis,
    values = temp.Tweet,
    title = {"position": "top center", "text": "Funnel-Chart of Sentiment Distribution"}
    ))
fig.show()

# %%
def clean_text(text):
    '''Make text lowercase, remove text in square brackets,remove links,remove punctuation
    and remove words containing numbers.'''
    text = str(text).lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = re.sub('\s-\s', ' ', text)
    text = re.sub('\.{2,}', '', text)
    return text

# %%
df['Tweet'] = df['Tweet'].apply(lambda x:clean_text(x))
df['temp_list'] = df['Tweet'].apply(lambda x:str(x).split())
def remove_stopword(x):
    return [y for y in x if y not in stopwords.words('english')]
df['temp_list'] = df['temp_list'].apply(lambda x:remove_stopword(x))

# %%
top = Counter([item for sublist in df['temp_list'] for item in sublist])
temp = pd.DataFrame(top.most_common(20))
temp = temp.iloc[1:,:]
temp.columns = ['Common_words','count']
temp.style.background_gradient(cmap='Purples')
# Out:
# <style type="text/css">
# #T_be5e0_row0_col1 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_be5e0_row1_col1 {
#   background-color: #dedded;
#   color: #000000;
# }
# #T_be5e0_row2_col1 {
#   background-color: #f1f0f6;
#   color: #000000;
# }
# #T_be5e0_row3_col1 {
#   background-color: #f2f0f7;
#   color: #000000;
# }
# #T_be5e0_row4_col1 {
#   background-color: #f4f2f8;
#   color: #000000;
# }
# #T_be5e0_row5_col1 {
#   background-color: #f7f6fa;
#   color: #000000;
# }
# #T_be5e0_row6_col1 {
#   background-color: #f8f6fa;
#   color: #000000;
# }
# #T_be5e0_row7_col1 {
#   background-color: #f8f7fa;
#   color: #000000;
# }
# #T_be5e0_row8_col1 {
#   background-color: #f8f7fb;
#   color: #000000;
# }
# #T_be5e0_row9_col1, #T_be5e0_row10_col1 {
#   background-color: #f9f7fb;
#   color: #000000;
# }
# #T_be5e0_row11_col1 {
#   background-color: #faf8fb;
#   color: #000000;
# }
# #T_be5e0_row12_col1 {
#   background-color: #faf9fc;
#   color: #000000;
# }
# #T_be5e0_row13_col1, #T_be5e0_row14_col1 {
#   background-color: #fbfafc;
#   color: #000000;
# }
# #T_be5e0_row15_col1, #T_be5e0_row16_col1, #T_be5e0_row17_col1, #T_be5e0_row18_col1 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# </style>
# <table id="T_be5e0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_be5e0_level0_col0" class="col_heading level0 col0" >Common_words</th>
#       <th id="T_be5e0_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_be5e0_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_be5e0_row0_col0" class="data row0 col0" >oscars</td>
#       <td id="T_be5e0_row0_col1" class="data row0 col1" >8723</td>
#     </tr>
#     <tr>
#       <th id="T_be5e0_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_be5e0_row1_col0" class="data row1 col0" >best</td>
#       <td id="T_be5e0_row1_col1" class="data row1 col1" >2942</td>
#     </tr>
#     <tr>
#       <th id="T_be5e0_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_be5e0_row2_col0" class="data row2 col0" >see</td>
#       <td id="T_be5e0_row2_col1" class="data row2 col1" >2005</td>
#     </tr>
#     <tr>
#       <th id="T_be5e0_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_be5e0_row3_col0" class="data row3 col0" >like</td>
#       <td id="T_be5e0_row3_col1" class="data row3 col1" >1977</td>
#     </tr>
#     <tr>
#       <th id="T_be5e0_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_be5e0_row4_col0" class="data row4 col0" >one</td>
#       <td id="T_be5e0_row4_col1" class="data row4 col1" >1835</td>
#     </tr>
#     <tr>
#       <th id="T_be5e0_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_be5e0_row5_col0" class="data row5 col0" >know</td>
#       <td id="T_be5e0_row5_col1" class="data row5 col1" >1594</td>
#     </tr>
#     <tr>
#       <th id="T_be5e0_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_be5e0_row6_col0" class="data row6 col0" >time</td>
#       <td id="T_be5e0_row6_col1" class="data row6 col1" >1559</td>
#     </tr>
#     <tr>
#       <th id="T_be5e0_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_be5e0_row7_col0" class="data row7 col0" >film</td>
#       <td id="T_be5e0_row7_col1" class="data row7 col1" >1518</td>
#     </tr>
#     <tr>
#       <th id="T_be5e0_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_be5e0_row8_col0" class="data row8 col0" >good</td>
#       <td id="T_be5e0_row8_col1" class="data row8 col1" >1512</td>
#     </tr>
#     <tr>
#       <th id="T_be5e0_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_be5e0_row9_col0" class="data row9 col0" >sunday</td>
#       <td id="T_be5e0_row9_col1" class="data row9 col1" >1461</td>
#     </tr>
#     <tr>
#       <th id="T_be5e0_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_be5e0_row10_col0" class="data row10 col0" >win</td>
#       <td id="T_be5e0_row10_col1" class="data row10 col1" >1457</td>
#     </tr>
#     <tr>
#       <th id="T_be5e0_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_be5e0_row11_col0" class="data row11 col0" >would</td>
#       <td id="T_be5e0_row11_col1" class="data row11 col1" >1410</td>
#     </tr>
#     <tr>
#       <th id="T_be5e0_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_be5e0_row12_col0" class="data row12 col0" >year</td>
#       <td id="T_be5e0_row12_col1" class="data row12 col1" >1355</td>
#     </tr>
#     <tr>
#       <th id="T_be5e0_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_be5e0_row13_col0" class="data row13 col0" >awards</td>
#       <td id="T_be5e0_row13_col1" class="data row13 col1" >1297</td>
#     </tr>
#     <tr>
#       <th id="T_be5e0_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_be5e0_row14_col0" class="data row14 col0" >people</td>
#       <td id="T_be5e0_row14_col1" class="data row14 col1" >1285</td>
#     </tr>
#     <tr>
#       <th id="T_be5e0_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_be5e0_row15_col0" class="data row15 col0" >movie</td>
#       <td id="T_be5e0_row15_col1" class="data row15 col1" >1280</td>
#     </tr>
#     <tr>
#       <th id="T_be5e0_level0_row16" class="row_heading level0 row16" >17</th>
#       <td id="T_be5e0_row16_col0" class="data row16 col0" >dont</td>
#       <td id="T_be5e0_row16_col1" class="data row16 col1" >1257</td>
#     </tr>
#     <tr>
#       <th id="T_be5e0_level0_row17" class="row_heading level0 row17" >18</th>
#       <td id="T_be5e0_row17_col0" class="data row17 col0" >get</td>
#       <td id="T_be5e0_row17_col1" class="data row17 col1" >1244</td>
#     </tr>
#     <tr>
#       <th id="T_be5e0_level0_row18" class="row_heading level0 row18" >19</th>
#       <td id="T_be5e0_row18_col0" class="data row18 col0" >think</td>
#       <td id="T_be5e0_row18_col1" class="data row18 col1" >1222</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = px.bar(temp, x="count", y="Common_words", title='Commmon Words in Selected Text', orientation='h', 
             width=700, height=700,color='Common_words')
fig.show()

# %%
fig = px.treemap(temp, path=['Common_words'], values='count',title='Tree of Most Common Words')
fig.show()

# %%
Positive_sent = df[df['TextBlob_Analysis']=='Positive']
Negative_sent = df[df['TextBlob_Analysis']=='Negative']
Neutral_sent = df[df['TextBlob_Analysis']=='Neutral']

# %%
#MosT common positive words
top = Counter([item for sublist in Positive_sent['temp_list'] for item in sublist])
temp_positive = pd.DataFrame(top.most_common(20))
temp_positive.columns = ['Common_words','count']
temp_positive.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_5bc86_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_5bc86_row1_col1 {
#   background-color: #339c52;
#   color: #f1f1f1;
# }
# #T_5bc86_row2_col1 {
#   background-color: #9cd797;
#   color: #000000;
# }
# #T_5bc86_row3_col1 {
#   background-color: #e4f5df;
#   color: #000000;
# }
# #T_5bc86_row4_col1 {
#   background-color: #e6f5e1;
#   color: #000000;
# }
# #T_5bc86_row5_col1 {
#   background-color: #edf8e9;
#   color: #000000;
# }
# #T_5bc86_row6_col1, #T_5bc86_row7_col1 {
#   background-color: #eff9eb;
#   color: #000000;
# }
# #T_5bc86_row8_col1 {
#   background-color: #f0f9ec;
#   color: #000000;
# }
# #T_5bc86_row9_col1 {
#   background-color: #f2faef;
#   color: #000000;
# }
# #T_5bc86_row10_col1, #T_5bc86_row11_col1 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# #T_5bc86_row12_col1, #T_5bc86_row13_col1, #T_5bc86_row14_col1 {
#   background-color: #f4fbf2;
#   color: #000000;
# }
# #T_5bc86_row15_col1 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_5bc86_row16_col1 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_5bc86_row17_col1, #T_5bc86_row18_col1 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_5bc86_row19_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_5bc86">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5bc86_level0_col0" class="col_heading level0 col0" >Common_words</th>
#       <th id="T_5bc86_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5bc86_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5bc86_row0_col0" class="data row0 col0" >oscar</td>
#       <td id="T_5bc86_row0_col1" class="data row0 col1" >6319</td>
#     </tr>
#     <tr>
#       <th id="T_5bc86_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5bc86_row1_col0" class="data row1 col0" >oscars</td>
#       <td id="T_5bc86_row1_col1" class="data row1 col1" >4528</td>
#     </tr>
#     <tr>
#       <th id="T_5bc86_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5bc86_row2_col0" class="data row2 col0" >best</td>
#       <td id="T_5bc86_row2_col1" class="data row2 col1" >2905</td>
#     </tr>
#     <tr>
#       <th id="T_5bc86_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5bc86_row3_col0" class="data row3 col0" >good</td>
#       <td id="T_5bc86_row3_col1" class="data row3 col1" >1448</td>
#     </tr>
#     <tr>
#       <th id="T_5bc86_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5bc86_row4_col0" class="data row4 col0" >win</td>
#       <td id="T_5bc86_row4_col1" class="data row4 col1" >1393</td>
#     </tr>
#     <tr>
#       <th id="T_5bc86_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_5bc86_row5_col0" class="data row5 col0" >film</td>
#       <td id="T_5bc86_row5_col1" class="data row5 col1" >1117</td>
#     </tr>
#     <tr>
#       <th id="T_5bc86_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_5bc86_row6_col0" class="data row6 col0" >one</td>
#       <td id="T_5bc86_row6_col1" class="data row6 col1" >1060</td>
#     </tr>
#     <tr>
#       <th id="T_5bc86_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_5bc86_row7_col0" class="data row7 col0" >see</td>
#       <td id="T_5bc86_row7_col1" class="data row7 col1" >1056</td>
#     </tr>
#     <tr>
#       <th id="T_5bc86_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_5bc86_row8_col0" class="data row8 col0" >like</td>
#       <td id="T_5bc86_row8_col1" class="data row8 col1" >1018</td>
#     </tr>
#     <tr>
#       <th id="T_5bc86_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_5bc86_row9_col0" class="data row9 col0" >time</td>
#       <td id="T_5bc86_row9_col1" class="data row9 col1" >927</td>
#     </tr>
#     <tr>
#       <th id="T_5bc86_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_5bc86_row10_col0" class="data row10 col0" >first</td>
#       <td id="T_5bc86_row10_col1" class="data row10 col1" >893</td>
#     </tr>
#     <tr>
#       <th id="T_5bc86_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_5bc86_row11_col0" class="data row11 col0" >movie</td>
#       <td id="T_5bc86_row11_col1" class="data row11 col1" >890</td>
#     </tr>
#     <tr>
#       <th id="T_5bc86_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_5bc86_row12_col0" class="data row12 col0" >would</td>
#       <td id="T_5bc86_row12_col1" class="data row12 col1" >838</td>
#     </tr>
#     <tr>
#       <th id="T_5bc86_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_5bc86_row13_col0" class="data row13 col0" >sunday</td>
#       <td id="T_5bc86_row13_col1" class="data row13 col1" >837</td>
#     </tr>
#     <tr>
#       <th id="T_5bc86_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_5bc86_row14_col0" class="data row14 col0" >love</td>
#       <td id="T_5bc86_row14_col1" class="data row14 col1" >833</td>
#     </tr>
#     <tr>
#       <th id="T_5bc86_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_5bc86_row15_col0" class="data row15 col0" >year</td>
#       <td id="T_5bc86_row15_col1" class="data row15 col1" >826</td>
#     </tr>
#     <tr>
#       <th id="T_5bc86_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_5bc86_row16_col0" class="data row16 col0" >know</td>
#       <td id="T_5bc86_row16_col1" class="data row16 col1" >789</td>
#     </tr>
#     <tr>
#       <th id="T_5bc86_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_5bc86_row17_col0" class="data row17 col0" >new</td>
#       <td id="T_5bc86_row17_col1" class="data row17 col1" >749</td>
#     </tr>
#     <tr>
#       <th id="T_5bc86_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_5bc86_row18_col0" class="data row18 col0" >awards</td>
#       <td id="T_5bc86_row18_col1" class="data row18 col1" >748</td>
#     </tr>
#     <tr>
#       <th id="T_5bc86_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_5bc86_row19_col0" class="data row19 col0" >much</td>
#       <td id="T_5bc86_row19_col1" class="data row19 col1" >723</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = px.bar(temp_positive, x="count", y="Common_words", title='Most Commmon Positive Words', orientation='h', 
             width=700, height=700,color='Common_words')
fig.show()

# %%
#MosT common negative words
top = Counter([item for sublist in Negative_sent['temp_list'] for item in sublist])
temp_negative = pd.DataFrame(top.most_common(20))
temp_negative = temp_negative.iloc[1:,:]
temp_negative.columns = ['Common_words','count']
temp_negative.style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_66d50_row0_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_66d50_row1_col1 {
#   background-color: #fcbea5;
#   color: #000000;
# }
# #T_66d50_row2_col1 {
#   background-color: #fdccb8;
#   color: #000000;
# }
# #T_66d50_row3_col1, #T_66d50_row4_col1 {
#   background-color: #fdd5c4;
#   color: #000000;
# }
# #T_66d50_row5_col1 {
#   background-color: #fedfd0;
#   color: #000000;
# }
# #T_66d50_row6_col1 {
#   background-color: #fee4d8;
#   color: #000000;
# }
# #T_66d50_row7_col1 {
#   background-color: #fee5d9;
#   color: #000000;
# }
# #T_66d50_row8_col1 {
#   background-color: #fee8de;
#   color: #000000;
# }
# #T_66d50_row9_col1 {
#   background-color: #feeae0;
#   color: #000000;
# }
# #T_66d50_row10_col1 {
#   background-color: #ffebe2;
#   color: #000000;
# }
# #T_66d50_row11_col1 {
#   background-color: #ffeee7;
#   color: #000000;
# }
# #T_66d50_row12_col1, #T_66d50_row13_col1 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_66d50_row14_col1 {
#   background-color: #fff2eb;
#   color: #000000;
# }
# #T_66d50_row15_col1 {
#   background-color: #fff3ed;
#   color: #000000;
# }
# #T_66d50_row16_col1 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_66d50_row17_col1 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_66d50_row18_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_66d50">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_66d50_level0_col0" class="col_heading level0 col0" >Common_words</th>
#       <th id="T_66d50_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_66d50_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_66d50_row0_col0" class="data row0 col0" >oscars</td>
#       <td id="T_66d50_row0_col1" class="data row0 col1" >1004</td>
#     </tr>
#     <tr>
#       <th id="T_66d50_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_66d50_row1_col0" class="data row1 col0" >like</td>
#       <td id="T_66d50_row1_col1" class="data row1 col1" >381</td>
#     </tr>
#     <tr>
#       <th id="T_66d50_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_66d50_row2_col0" class="data row2 col0" >one</td>
#       <td id="T_66d50_row2_col1" class="data row2 col1" >340</td>
#     </tr>
#     <tr>
#       <th id="T_66d50_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_66d50_row3_col0" class="data row3 col0" >bad</td>
#       <td id="T_66d50_row3_col1" class="data row3 col1" >315</td>
#     </tr>
#     <tr>
#       <th id="T_66d50_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_66d50_row4_col0" class="data row4 col0" >people</td>
#       <td id="T_66d50_row4_col1" class="data row4 col1" >315</td>
#     </tr>
#     <tr>
#       <th id="T_66d50_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_66d50_row5_col0" class="data row5 col0" >see</td>
#       <td id="T_66d50_row5_col1" class="data row5 col1" >291</td>
#     </tr>
#     <tr>
#       <th id="T_66d50_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_66d50_row6_col0" class="data row6 col0" >know</td>
#       <td id="T_66d50_row6_col1" class="data row6 col1" >266</td>
#     </tr>
#     <tr>
#       <th id="T_66d50_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_66d50_row7_col0" class="data row7 col0" >would</td>
#       <td id="T_66d50_row7_col1" class="data row7 col1" >262</td>
#     </tr>
#     <tr>
#       <th id="T_66d50_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_66d50_row8_col0" class="data row8 col0" >time</td>
#       <td id="T_66d50_row8_col1" class="data row8 col1" >244</td>
#     </tr>
#     <tr>
#       <th id="T_66d50_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_66d50_row9_col0" class="data row9 col0" >dont</td>
#       <td id="T_66d50_row9_col1" class="data row9 col1" >239</td>
#     </tr>
#     <tr>
#       <th id="T_66d50_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_66d50_row10_col0" class="data row10 col0" >get</td>
#       <td id="T_66d50_row10_col1" class="data row10 col1" >231</td>
#     </tr>
#     <tr>
#       <th id="T_66d50_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_66d50_row11_col0" class="data row11 col0" >little</td>
#       <td id="T_66d50_row11_col1" class="data row11 col1" >216</td>
#     </tr>
#     <tr>
#       <th id="T_66d50_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_66d50_row12_col0" class="data row12 col0" >go</td>
#       <td id="T_66d50_row12_col1" class="data row12 col1" >209</td>
#     </tr>
#     <tr>
#       <th id="T_66d50_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_66d50_row13_col0" class="data row13 col0" >shit</td>
#       <td id="T_66d50_row13_col1" class="data row13 col1" >208</td>
#     </tr>
#     <tr>
#       <th id="T_66d50_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_66d50_row14_col0" class="data row14 col0" >think</td>
#       <td id="T_66d50_row14_col1" class="data row14 col1" >199</td>
#     </tr>
#     <tr>
#       <th id="T_66d50_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_66d50_row15_col0" class="data row15 col0" >im</td>
#       <td id="T_66d50_row15_col1" class="data row15 col1" >192</td>
#     </tr>
#     <tr>
#       <th id="T_66d50_level0_row16" class="row_heading level0 row16" >17</th>
#       <td id="T_66d50_row16_col0" class="data row16 col0" >already</td>
#       <td id="T_66d50_row16_col1" class="data row16 col1" >190</td>
#     </tr>
#     <tr>
#       <th id="T_66d50_level0_row17" class="row_heading level0 row17" >18</th>
#       <td id="T_66d50_row17_col0" class="data row17 col0" >years</td>
#       <td id="T_66d50_row17_col1" class="data row17 col1" >186</td>
#     </tr>
#     <tr>
#       <th id="T_66d50_level0_row18" class="row_heading level0 row18" >19</th>
#       <td id="T_66d50_row18_col0" class="data row18 col0" >want</td>
#       <td id="T_66d50_row18_col1" class="data row18 col1" >182</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = px.treemap(temp_negative, path=['Common_words'], values='count',title='Tree Of Most Common Negative Words')
fig.show()

# %%
#MosT common Neutral words
top = Counter([item for sublist in Neutral_sent['temp_list'] for item in sublist])
temp_neutral = pd.DataFrame(top.most_common(20))
temp_neutral = temp_neutral.loc[1:,:]
temp_neutral.columns = ['Common_words','count']
temp_neutral.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_ddba4_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_ddba4_row1_col1 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_ddba4_row2_col1 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_ddba4_row3_col1 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_ddba4_row4_col1 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_ddba4_row5_col1, #T_ddba4_row6_col1 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_ddba4_row7_col1 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_ddba4_row8_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_ddba4_row9_col1, #T_ddba4_row10_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_ddba4_row11_col1 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_ddba4_row12_col1, #T_ddba4_row13_col1 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_ddba4_row14_col1, #T_ddba4_row15_col1 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_ddba4_row16_col1, #T_ddba4_row17_col1, #T_ddba4_row18_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_ddba4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ddba4_level0_col0" class="col_heading level0 col0" >Common_words</th>
#       <th id="T_ddba4_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ddba4_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_ddba4_row0_col0" class="data row0 col0" >oscars</td>
#       <td id="T_ddba4_row0_col1" class="data row0 col1" >3191</td>
#     </tr>
#     <tr>
#       <th id="T_ddba4_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_ddba4_row1_col0" class="data row1 col0" >see</td>
#       <td id="T_ddba4_row1_col1" class="data row1 col1" >658</td>
#     </tr>
#     <tr>
#       <th id="T_ddba4_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_ddba4_row2_col0" class="data row2 col0" >like</td>
#       <td id="T_ddba4_row2_col1" class="data row2 col1" >578</td>
#     </tr>
#     <tr>
#       <th id="T_ddba4_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_ddba4_row3_col0" class="data row3 col0" >know</td>
#       <td id="T_ddba4_row3_col1" class="data row3 col1" >539</td>
#     </tr>
#     <tr>
#       <th id="T_ddba4_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_ddba4_row4_col0" class="data row4 col0" >sunday</td>
#       <td id="T_ddba4_row4_col1" class="data row4 col1" >514</td>
#     </tr>
#     <tr>
#       <th id="T_ddba4_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_ddba4_row5_col0" class="data row5 col0" >dont</td>
#       <td id="T_ddba4_row5_col1" class="data row5 col1" >435</td>
#     </tr>
#     <tr>
#       <th id="T_ddba4_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_ddba4_row6_col0" class="data row6 col0" >one</td>
#       <td id="T_ddba4_row6_col1" class="data row6 col1" >435</td>
#     </tr>
#     <tr>
#       <th id="T_ddba4_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_ddba4_row7_col0" class="data row7 col0" >awards</td>
#       <td id="T_ddba4_row7_col1" class="data row7 col1" >417</td>
#     </tr>
#     <tr>
#       <th id="T_ddba4_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_ddba4_row8_col0" class="data row8 col0" >time</td>
#       <td id="T_ddba4_row8_col1" class="data row8 col1" >388</td>
#     </tr>
#     <tr>
#       <th id="T_ddba4_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_ddba4_row9_col0" class="data row9 col0" >already</td>
#       <td id="T_ddba4_row9_col1" class="data row9 col1" >376</td>
#     </tr>
#     <tr>
#       <th id="T_ddba4_level0_row10" class="row_heading level0 row10" >11</th>
#       <td id="T_ddba4_row10_col0" class="data row10 col0" >want</td>
#       <td id="T_ddba4_row10_col1" class="data row10 col1" >372</td>
#     </tr>
#     <tr>
#       <th id="T_ddba4_level0_row11" class="row_heading level0 row11" >12</th>
#       <td id="T_ddba4_row11_col0" class="data row11 col0" >year</td>
#       <td id="T_ddba4_row11_col1" class="data row11 col1" >353</td>
#     </tr>
#     <tr>
#       <th id="T_ddba4_level0_row12" class="row_heading level0 row12" >13</th>
#       <td id="T_ddba4_row12_col0" class="data row12 col0" >watch</td>
#       <td id="T_ddba4_row12_col1" class="data row12 col1" >346</td>
#     </tr>
#     <tr>
#       <th id="T_ddba4_level0_row13" class="row_heading level0 row13" >14</th>
#       <td id="T_ddba4_row13_col0" class="data row13 col0" >go</td>
#       <td id="T_ddba4_row13_col1" class="data row13 col1" >341</td>
#     </tr>
#     <tr>
#       <th id="T_ddba4_level0_row14" class="row_heading level0 row14" >15</th>
#       <td id="T_ddba4_row14_col0" class="data row14 col0" >going</td>
#       <td id="T_ddba4_row14_col1" class="data row14 col1" >333</td>
#     </tr>
#     <tr>
#       <th id="T_ddba4_level0_row15" class="row_heading level0 row15" >16</th>
#       <td id="T_ddba4_row15_col0" class="data row15 col0" >get</td>
#       <td id="T_ddba4_row15_col1" class="data row15 col1" >332</td>
#     </tr>
#     <tr>
#       <th id="T_ddba4_level0_row16" class="row_heading level0 row16" >17</th>
#       <td id="T_ddba4_row16_col0" class="data row16 col0" >nominated</td>
#       <td id="T_ddba4_row16_col1" class="data row16 col1" >320</td>
#     </tr>
#     <tr>
#       <th id="T_ddba4_level0_row17" class="row_heading level0 row17" >18</th>
#       <td id="T_ddba4_row17_col0" class="data row17 col0" >people</td>
#       <td id="T_ddba4_row17_col1" class="data row17 col1" >319</td>
#     </tr>
#     <tr>
#       <th id="T_ddba4_level0_row18" class="row_heading level0 row18" >19</th>
#       <td id="T_ddba4_row18_col0" class="data row18 col0" >us</td>
#       <td id="T_ddba4_row18_col1" class="data row18 col1" >315</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = px.bar(temp_neutral, x="count", y="Common_words", title='Most Commmon Neutral Words', orientation='h', 
             width=700, height=700,color='Common_words')
fig.show()

# %%
fig = px.treemap(temp_neutral, path=['Common_words'], values='count',title='Tree Of Most Common Neutral Words')
fig.show()

# %%
df['temp_list1'] = df['Tweet'].apply(lambda x:str(x).split()) #List of words in every row for text
df['temp_list1'] = df['temp_list1'].apply(lambda x:remove_stopword(x)) #Removing Stopwords
raw_text = [word for word_list in df['temp_list1'] for word in word_list]

# %%
def words_unique(sentiment,numwords,raw_words):
    '''
    Input:
        segment - Segment category (ex. 'Neutral');
        numwords - how many specific words do you want to see in the final result; 
        raw_words - list  for item in train_data[train_data.segments == segments]['temp_list1']:
    Output: 
        dataframe giving information about the name of the specific ingredient and how many times it occurs in the chosen cuisine (in descending order based on their counts)..

    '''
    allother = []
    for item in df[df.TextBlob_Analysis != sentiment]['temp_list1']:
        for word in item:
            allother .append(word)
    allother  = list(set(allother ))
    
    specificnonly = [x for x in raw_text if x not in allother]
    
    mycounter = Counter()
    
    for item in df[df.TextBlob_Analysis == sentiment]['temp_list1']:
        for word in item:
            mycounter[word] += 1
    keep = list(specificnonly)
    
    for word in list(mycounter):
        if word not in keep:
            del mycounter[word]
    
    Unique_words = pd.DataFrame(mycounter.most_common(numwords), columns = ['words','count'])
    
    return Unique_words

# %%
Unique_Positive= words_unique('Positive', 20, raw_text)
print("The top 20 unique words in Positive Tweets are:")
Unique_Positive.style.background_gradient(cmap='Greens')
# Out:
# The top 20 unique words in Positive Tweets are:
# <style type="text/css">
# #T_dbf10_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_dbf10_row1_col1 {
#   background-color: #7fc97f;
#   color: #000000;
# }
# #T_dbf10_row2_col1 {
#   background-color: #bee5b8;
#   color: #000000;
# }
# #T_dbf10_row3_col1 {
#   background-color: #c1e6ba;
#   color: #000000;
# }
# #T_dbf10_row4_col1 {
#   background-color: #dff3da;
#   color: #000000;
# }
# #T_dbf10_row5_col1 {
#   background-color: #e1f3dc;
#   color: #000000;
# }
# #T_dbf10_row6_col1, #T_dbf10_row7_col1 {
#   background-color: #e3f4de;
#   color: #000000;
# }
# #T_dbf10_row8_col1 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_dbf10_row9_col1 {
#   background-color: #ecf8e8;
#   color: #000000;
# }
# #T_dbf10_row10_col1 {
#   background-color: #edf8ea;
#   color: #000000;
# }
# #T_dbf10_row11_col1, #T_dbf10_row12_col1 {
#   background-color: #f4fbf1;
#   color: #000000;
# }
# #T_dbf10_row13_col1, #T_dbf10_row14_col1 {
#   background-color: #f5fbf2;
#   color: #000000;
# }
# #T_dbf10_row15_col1 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_dbf10_row16_col1 {
#   background-color: #f6fcf4;
#   color: #000000;
# }
# #T_dbf10_row17_col1, #T_dbf10_row18_col1, #T_dbf10_row19_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_dbf10">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dbf10_level0_col0" class="col_heading level0 col0" >words</th>
#       <th id="T_dbf10_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dbf10_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dbf10_row0_col0" class="data row0 col0" >original</td>
#       <td id="T_dbf10_row0_col1" class="data row0 col1" >183</td>
#     </tr>
#     <tr>
#       <th id="T_dbf10_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dbf10_row1_col0" class="data row1 col0" >wonderful</td>
#       <td id="T_dbf10_row1_col1" class="data row1 col1" >98</td>
#     </tr>
#     <tr>
#       <th id="T_dbf10_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dbf10_row2_col0" class="data row2 col0" >iconic</td>
#       <td id="T_dbf10_row2_col1" class="data row2 col1" >67</td>
#     </tr>
#     <tr>
#       <th id="T_dbf10_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_dbf10_row3_col0" class="data row3 col0" >greatest</td>
#       <td id="T_dbf10_row3_col1" class="data row3 col1" >66</td>
#     </tr>
#     <tr>
#       <th id="T_dbf10_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_dbf10_row4_col0" class="data row4 col0" >brilliant</td>
#       <td id="T_dbf10_row4_col1" class="data row4 col1" >46</td>
#     </tr>
#     <tr>
#       <th id="T_dbf10_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_dbf10_row5_col0" class="data row5 col0" >joy</td>
#       <td id="T_dbf10_row5_col1" class="data row5 col1" >45</td>
#     </tr>
#     <tr>
#       <th id="T_dbf10_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_dbf10_row6_col0" class="data row6 col0" >safe</td>
#       <td id="T_dbf10_row6_col1" class="data row6 col1" >44</td>
#     </tr>
#     <tr>
#       <th id="T_dbf10_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_dbf10_row7_col0" class="data row7 col0" >🌸</td>
#       <td id="T_dbf10_row7_col1" class="data row7 col1" >44</td>
#     </tr>
#     <tr>
#       <th id="T_dbf10_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_dbf10_row8_col0" class="data row8 col0" >successful</td>
#       <td id="T_dbf10_row8_col1" class="data row8 col1" >38</td>
#     </tr>
#     <tr>
#       <th id="T_dbf10_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_dbf10_row9_col0" class="data row9 col0" >♥</td>
#       <td id="T_dbf10_row9_col1" class="data row9 col1" >35</td>
#     </tr>
#     <tr>
#       <th id="T_dbf10_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_dbf10_row10_col0" class="data row10 col0" >creative</td>
#       <td id="T_dbf10_row10_col1" class="data row10 col1" >33</td>
#     </tr>
#     <tr>
#       <th id="T_dbf10_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_dbf10_row11_col0" class="data row11 col0" >inspirational</td>
#       <td id="T_dbf10_row11_col1" class="data row11 col1" >26</td>
#     </tr>
#     <tr>
#       <th id="T_dbf10_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_dbf10_row12_col0" class="data row12 col0" >impressive</td>
#       <td id="T_dbf10_row12_col1" class="data row12 col1" >26</td>
#     </tr>
#     <tr>
#       <th id="T_dbf10_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_dbf10_row13_col0" class="data row13 col0" >awesome</td>
#       <td id="T_dbf10_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_dbf10_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_dbf10_row14_col0" class="data row14 col0" >perfectly</td>
#       <td id="T_dbf10_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_dbf10_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_dbf10_row15_col0" class="data row15 col0" >spectacular</td>
#       <td id="T_dbf10_row15_col1" class="data row15 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_dbf10_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_dbf10_row16_col0" class="data row16 col0" >“best</td>
#       <td id="T_dbf10_row16_col1" class="data row16 col1" >23</td>
#     </tr>
#     <tr>
#       <th id="T_dbf10_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_dbf10_row17_col0" class="data row17 col0" >💝</td>
#       <td id="T_dbf10_row17_col1" class="data row17 col1" >22</td>
#     </tr>
#     <tr>
#       <th id="T_dbf10_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_dbf10_row18_col0" class="data row18 col0" >gorgeous</td>
#       <td id="T_dbf10_row18_col1" class="data row18 col1" >22</td>
#     </tr>
#     <tr>
#       <th id="T_dbf10_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_dbf10_row19_col0" class="data row19 col0" >grand</td>
#       <td id="T_dbf10_row19_col1" class="data row19 col1" >22</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig = px.treemap(Unique_Positive, path=['words'], values='count',title='Tree Of Unique Positive Words')
fig.show()

# %%
plt.figure(figsize=(16,10))
my_circle=plt.Circle((0,0), 0.7, color='white')
plt.pie(Unique_Positive['count'], labels=Unique_Positive.words, colors=Pastel1_7.hex_colors)
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.title('DoNut Plot Of Unique Positive Words')
plt.show()
# Out:
# C:\Users\17mar\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning:
#
# Glyph 127800 (\N{CHERRY BLOSSOM}) missing from current font.
#
# C:\Users\17mar\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning:
#
# Glyph 128157 (\N{HEART WITH RIBBON}) missing from current font.

# %%
Unique_Negative= words_unique('Negative', 10, raw_text)
print("The top 10 unique words in Negative Tweets are:")
Unique_Negative.style.background_gradient(cmap='Reds')
# Out:
# The top 10 unique words in Negative Tweets are:
# <style type="text/css">
# #T_28c31_row0_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_28c31_row1_col1 {
#   background-color: #ec382b;
#   color: #f1f1f1;
# }
# #T_28c31_row2_col1 {
#   background-color: #f7593f;
#   color: #f1f1f1;
# }
# #T_28c31_row3_col1 {
#   background-color: #fb7858;
#   color: #f1f1f1;
# }
# #T_28c31_row4_col1 {
#   background-color: #fc9576;
#   color: #000000;
# }
# #T_28c31_row5_col1 {
#   background-color: #fdd0bc;
#   color: #000000;
# }
# #T_28c31_row6_col1, #T_28c31_row7_col1 {
#   background-color: #fee6da;
#   color: #000000;
# }
# #T_28c31_row8_col1, #T_28c31_row9_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_28c31">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_28c31_level0_col0" class="col_heading level0 col0" >words</th>
#       <th id="T_28c31_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_28c31_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_28c31_row0_col0" class="data row0 col0" >deficiency</td>
#       <td id="T_28c31_row0_col1" class="data row0 col1" >17</td>
#     </tr>
#     <tr>
#       <th id="T_28c31_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_28c31_row1_col0" class="data row1 col0" >mere</td>
#       <td id="T_28c31_row1_col1" class="data row1 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_28c31_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_28c31_row2_col0" class="data row2 col0" >nasty</td>
#       <td id="T_28c31_row2_col1" class="data row2 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_28c31_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_28c31_row3_col0" class="data row3 col0" >painful</td>
#       <td id="T_28c31_row3_col1" class="data row3 col1" >11</td>
#     </tr>
#     <tr>
#       <th id="T_28c31_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_28c31_row4_col0" class="data row4 col0" >negreria</td>
#       <td id="T_28c31_row4_col1" class="data row4 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_28c31_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_28c31_row5_col0" class="data row5 col0" >homicide</td>
#       <td id="T_28c31_row5_col1" class="data row5 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_28c31_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_28c31_row6_col0" class="data row6 col0" >sexuality</td>
#       <td id="T_28c31_row6_col1" class="data row6 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_28c31_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_28c31_row7_col0" class="data row7 col0" >rosell👉</td>
#       <td id="T_28c31_row7_col1" class="data row7 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_28c31_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_28c31_row8_col0" class="data row8 col0" >ballistic</td>
#       <td id="T_28c31_row8_col1" class="data row8 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_28c31_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_28c31_row9_col0" class="data row9 col0" >worthless</td>
#       <td id="T_28c31_row9_col1" class="data row9 col1" >6</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.figure(figsize=(16,10))
my_circle=plt.Circle((0,0), 0.7, color='white')
plt.rcParams['text.color'] = 'black'
plt.pie(Unique_Negative['count'], labels=Unique_Negative.words, colors=Pastel1_7.hex_colors)
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.title('DoNut Plot Of Unique Negative Words')
plt.show()
# Out:
# C:\Users\17mar\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning:
#
# Glyph 128073 (\N{WHITE RIGHT POINTING BACKHAND INDEX}) missing from current font.

# %%
Unique_Neutral= words_unique('Neutral', 10, raw_text)
print("The top 10 unique words in Neutral Tweets are:")
Unique_Neutral.style.background_gradient(cmap='Oranges')
# Out:
# The top 10 unique words in Neutral Tweets are:
# <style type="text/css">
# #T_b5a42_row0_col1 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_b5a42_row1_col1 {
#   background-color: #ef6612;
#   color: #f1f1f1;
# }
# #T_b5a42_row2_col1 {
#   background-color: #fdce9e;
#   color: #000000;
# }
# #T_b5a42_row3_col1 {
#   background-color: #fddab6;
#   color: #000000;
# }
# #T_b5a42_row4_col1 {
#   background-color: #fee1c4;
#   color: #000000;
# }
# #T_b5a42_row5_col1, #T_b5a42_row6_col1 {
#   background-color: #fee9d3;
#   color: #000000;
# }
# #T_b5a42_row7_col1 {
#   background-color: #fff2e6;
#   color: #000000;
# }
# #T_b5a42_row8_col1, #T_b5a42_row9_col1 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# </style>
# <table id="T_b5a42">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b5a42_level0_col0" class="col_heading level0 col0" >words</th>
#       <th id="T_b5a42_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b5a42_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b5a42_row0_col0" class="data row0 col0" >juancaosh</td>
#       <td id="T_b5a42_row0_col1" class="data row0 col1" >99</td>
#     </tr>
#     <tr>
#       <th id="T_b5a42_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b5a42_row1_col0" class="data row1 col0" >guangzhou</td>
#       <td id="T_b5a42_row1_col1" class="data row1 col1" >71</td>
#     </tr>
#     <tr>
#       <th id="T_b5a42_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b5a42_row2_col0" class="data row2 col0" >hangzhou</td>
#       <td id="T_b5a42_row2_col1" class="data row2 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_b5a42_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b5a42_row3_col0" class="data row3 col0" >💕😍</td>
#       <td id="T_b5a42_row3_col1" class="data row3 col1" >37</td>
#     </tr>
#     <tr>
#       <th id="T_b5a42_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b5a42_row4_col0" class="data row4 col0" >🔔</td>
#       <td id="T_b5a42_row4_col1" class="data row4 col1" >34</td>
#     </tr>
#     <tr>
#       <th id="T_b5a42_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b5a42_row5_col0" class="data row5 col0" >shanghai</td>
#       <td id="T_b5a42_row5_col1" class="data row5 col1" >30</td>
#     </tr>
#     <tr>
#       <th id="T_b5a42_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b5a42_row6_col0" class="data row6 col0" >🕯</td>
#       <td id="T_b5a42_row6_col1" class="data row6 col1" >30</td>
#     </tr>
#     <tr>
#       <th id="T_b5a42_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b5a42_row7_col0" class="data row7 col0" >snafu</td>
#       <td id="T_b5a42_row7_col1" class="data row7 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_b5a42_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b5a42_row8_col0" class="data row8 col0" >longoverdue</td>
#       <td id="T_b5a42_row8_col1" class="data row8 col1" >22</td>
#     </tr>
#     <tr>
#       <th id="T_b5a42_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b5a42_row9_col0" class="data row9 col0" >porsche</td>
#       <td id="T_b5a42_row9_col1" class="data row9 col1" >22</td>
#     </tr>
#   </tbody>
# </table>

# %%
plt.figure(figsize=(16,10))
my_circle=plt.Circle((0,0), 0.7, color='white')
plt.pie(Unique_Neutral['count'], labels=Unique_Neutral.words, colors=Pastel1_7.hex_colors)
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.title('DoNut Plot Of Unique Neutral Words')
plt.show()
# Out:
# C:\Users\17mar\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning:
#
# Glyph 128149 (\N{TWO HEARTS}) missing from current font.
#
# C:\Users\17mar\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning:
#
# Glyph 128276 (\N{BELL}) missing from current font.
#
# C:\Users\17mar\AppData\Roaming\Python\Python311\site-packages\IPython\core\pylabtools.py:152: UserWarning:
#
# Glyph 128367 (\N{CANDLE}) missing from current font.

# %%
def plot_wordcloud(text, mask=None, max_words=200, max_font_size=100, figure_size=(24.0,16.0), color = 'white',
                   title = None, title_size=40, image_color=False):
    stopwords = set(STOPWORDS)
    more_stopwords = {'u', "im"}
    stopwords = stopwords.union(more_stopwords)

    wordcloud = WordCloud(background_color=color,
                    stopwords = stopwords,
                    max_words = max_words,
                    max_font_size = max_font_size, 
                    random_state = 42,
                    width=400, 
                    height=200,
                    mask = mask)
    wordcloud.generate(str(text))
    
    plt.figure(figsize=figure_size)
    if image_color:
        image_colors = ImageColorGenerator(mask);
        plt.imshow(wordcloud.recolor(color_func=image_colors), interpolation="bilinear");
        plt.title(title, fontdict={'size': title_size,  
                                  'verticalalignment': 'bottom'})
    else:
        plt.imshow(wordcloud);
        plt.title(title, fontdict={'size': title_size, 'color': 'black', 
                                  'verticalalignment': 'bottom'})
    plt.axis('off');
    plt.tight_layout()

# %%
pos_mask = np.array(Image.open('statue.png'))
plot_wordcloud(Neutral_sent.Tweet,mask=pos_mask,color='white',max_font_size=100,title_size=30,title="WordCloud of Neutral Tweets")

# %%
plot_wordcloud(Positive_sent.Tweet,mask=pos_mask,title="Word Cloud Of Positive tweets",title_size=30)

# %%
# Filtrar el dataframe para excluir los valores de 0 y 1
df_filtrado = df[(df['TextBlob_Subjectivity'] > 0) & (df['TextBlob_Subjectivity'] < 1) & (df['TextBlob_Subjectivity'] != 0.5)]

# Agrupar los datos filtrados y contar el número de registros en cada grupo
conteo_por_grupo = df_filtrado.groupby('TextBlob_Subjectivity').count()

# Crear una gráfica de dispersión
plt.scatter(conteo_por_grupo.index, conteo_por_grupo['TextBlob_Analysis'])

# Configurar los títulos y etiquetas de los ejes
plt.title('Gráfica de dispersión de la columna TextBlob_Subjectivity')
plt.xlabel('TextBlob_Subjectivity')
plt.ylabel('Número de registros')

# Mostrar la gráfica
plt.show()

# %%
# Crear una matriz de datos con el número de registros en cada bin
bins = np.linspace(0, 1, num=21)
conteo_por_bin = pd.cut(df_filtrado['TextBlob_Subjectivity'], bins=bins).value_counts().sort_index().values
matriz_datos = conteo_por_bin.reshape(20, 1)

# Crear un heatmap con la matriz de datos
sns.heatmap(matriz_datos, cmap='Blues', xticklabels=False, yticklabels=False, cbar_kws={'label': 'Número de registros'})

# Configurar los títulos y etiquetas
plt.title('Heatmap de la columna TextBlob_Subjectivity')
plt.xlabel('Número de registros')
plt.ylabel('TextBlob_Subjectivity')

# Mostrar el heatmap
plt.show()

# %%
print(conteo_por_grupo.columns)
# Out:
# Index(['Unnamed: 0', 'User', 'Date Created', 'Number of Likes',
#        'Source of Tweet', 'Tweet', 'TextBlob_Polarity', 'TextBlob_Analysis',
#        'temp_list', 'temp_list1'],
#       dtype='object')
